# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
brian_df = pd.read_csv('/content/drive/MyDrive/Hackathon 2021 State Data/csv files/brian data.csv')

# %%
brian_df.head()
# Out:
#    Unnamed: 0         State  ... Sheep and lambs    Turkeys
# 0           0  Pennsylvania  ...           2,087        138
# 1           1     Tennessee  ...             622        (D)
# 2           2    California  ...          30,883  1,080,017
# 3           3     Tennessee  ...             262        (D)
# 4           4  Pennsylvania  ...           1,436        233
#
# [5 rows x 25 columns]

# %%
brian_df.columns
# Out:
# Index(['Unnamed: 0', 'State', 'County', 'Number of Farms', 'Land in Farms',
#        'Average Size of Farms', 'Farm Size 1-9 acres', 'Farm Size 10-49 acres',
#        'Farm Size 50-179 acres', 'Farm Size 180-499', 'Farm Size 500-999',
#        'Farm Size 1000+', 'Cropland', 'Pastureland', 'Woodland', 'Other',
#        'Broilers and other meat-type chickens', 'Cattle and calves', 'Goats',
#        'Hogs and pigs', 'Horses and ponies', 'Layers', 'Pullets',
#        'Sheep and lambs', 'Turkeys'],
#       dtype='object')

# %%
brian_df["Turkeys"].value_counts()["(D)"]
# Out:
# 226

# %%
brian_df.drop(columns="Unnamed: 0", inplace=True)

# %%
brian_df2 = pd.DataFrame(brian_df, columns=['State', 'County', 'Number of Farms', 'Land in Farms',
       'Average Size of Farms', 'Farm Size 1-9 acres', 'Farm Size 10-49 acres',
       'Farm Size 50-179 acres', 'Farm Size 180-499', 'Farm Size 500-999',
       'Farm Size 1000+', 'Pastureland', 'Broilers and other meat-type chickens', 'Cattle and calves', 'Hogs and pigs', 'Sheep and lambs'])

# %%
for col in brian_df2.columns:
    print("---- %s ---" % col)
    print(brian_df2[col].value_counts())
# Out:
# ---- State ---
# Georgia           159
# Illinois          102
# Tennessee          95
# Oklahoma           77
# Arkansas           75
# Alabama            67
# Pennsylvania       67
# Florida            67
# Colorado           63
# California         58
# South Carolina     46
# Idaho              44
# Oregon             36
# Arizona            15
# Connecticut         8
# Alaska              5
# Rhode Island        5
# Hawaii              4
# Delaware            3
# Name: State, dtype: int64
# ---- County ---
# Washington County     12
# Jefferson County      11
# Jackson County         9
# Franklin County        8
# Marion County          8
#                       ..
# Beckham County         1
# Duval County           1
# Amador County          1
# San Joaquin County     1
# Etowah County          1
# Name: County, Length: 711, dtype: int64
# ---- Number of Farms ---
# 377      5
# 287      5
# 197      4
# 190      4
# 381      4
#         ..
# 751      1
# 756      1
# ...

# %%
brian_df2.shape
# Out:
# (996, 16)

# %%
brian_df2.loc[brian_df2.index.isin(["(D)"])]
# Out:
# Empty DataFrame
# Columns: [State, County, Number of Farms, Land in Farms, Average Size of Farms, Farm Size 1-9 acres, Farm Size 10-49 acres, Farm Size 50-179 acres, Farm Size 180-499, Farm Size 500-999, Farm Size 1000+, Pastureland, Broilers and other meat-type chickens, Cattle and calves, Hogs and pigs, Sheep and lambs]
# Index: []

# %%
claire_df = pd.read_csv('/content/drive/MyDrive/Hackathon 2021 State Data/csv files/claire data.csv')

# %%
claire_df.drop(columns="Unnamed: 0", inplace=True)

# %%
claire_df2 = pd.DataFrame(claire_df, columns=['State', 'County', 'Number of Farms', 'Land in Farms',
       'Average Size of Farms', 'Farm Size 1-9 acres', 'Farm Size 10-49 acres',
       'Farm Size 50-179 acres', 'Farm Size 180-499', 'Farm Size 500-999',
       'Farm Size 1000+', 'Pastureland', 'Broilers and other meat-type chickens', 'Cattle and calves', 'Hogs and pigs', 'Sheep and lambs'])

# %%
han_df = pd.read_csv('/content/drive/MyDrive/Hackathon 2021 State Data/csv files/han data.csv')

# %%
han_df.drop(columns="Unnamed: 0", inplace=True)

# %%
han_df2 = pd.DataFrame(han_df, columns=['State', 'County', 'Number of Farms', 'Land in Farms',
       'Average Size of Farms', 'Farm Size 1-9 acres', 'Farm Size 10-49 acres',
       'Farm Size 50-179 acres', 'Farm Size 180-499', 'Farm Size 500-999',
       'Farm Size 1000+', 'Pastureland', 'Broilers and other meat-type chickens', 'Cattle and calves', 'Hogs and pigs', 'Sheep and lambs'])

# %%
sally_df = pd.read_csv('/content/drive/MyDrive/Hackathon 2021 State Data/csv files/sally.csv')

# %%
sally_df.drop(columns="Unnamed: 0", inplace=True)

# %%
sally_df2 = pd.DataFrame(sally_df, columns=['State', 'County', 'Number of Farms', 'Land in Farms',
       'Average Size of Farms', 'Farm Size 1-9 acres', 'Farm Size 10-49 acres',
       'Farm Size 50-179 acres', 'Farm Size 180-499', 'Farm Size 500-999',
       'Farm Size 1000+', 'Pastureland', 'Broilers and other meat-type chickens', 'Cattle and calves', 'Hogs and pigs', 'Sheep and lambs'])

# %%
samson_df = pd.read_csv('/content/drive/MyDrive/Hackathon 2021 State Data/csv files/samson data.csv')

# %%
samson_df.drop(columns="Unnamed: 0", inplace=True)

# %%
samson_df2 = pd.DataFrame(samson_df, columns=['State', 'County', 'Number of Farms', 'Land in Farms',
       'Average Size of Farms', 'Farm Size 1-9 acres', 'Farm Size 10-49 acres',
       'Farm Size 50-179 acres', 'Farm Size 180-499', 'Farm Size 500-999',
       'Farm Size 1000+', 'Pastureland', 'Broilers and other meat-type chickens', 'Cattle and calves', 'Hogs and pigs', 'Sheep and lambs'])

# %%
farm_data = pd.concat([brian_df2, claire_df2, han_df2, sally_df2, samson_df2])

# %%
farm_data[np.equal.outer(farm_data.to_numpy(copy=False),  ['(D)']).any(axis=1).all(axis=1)]
# Out:
#             State               County  ... Hogs and pigs Sheep and lambs
# 5      California         Kings County  ...           129             (D)
# 6      California      Imperial County  ...           (D)          48,079
# 7    Pennsylvania  Philadelphia County  ...            22             (D)
# 12      Tennessee         Obion County  ...           (D)             386
# 15   Pennsylvania    Huntingdon County  ...        19,408           1,118
# ..            ...                  ...  ...           ...             ...
# 468      Nebraska        Garden County  ...            95             173
# 469      Nebraska       Perkins County  ...           (D)             254
# 471      Nebraska       Merrick County  ...           (D)             478
# 472      Nebraska     Lancaster County  ...        24,059           1,046
# 473          Ohio       Carroll County  ...           (D)           1,712
#
# [1105 rows x 16 columns]

# %%
farm_data['Broilers and other meat-type chickens'].value_counts()
# Out:
# (D)          584
# -            399
# 60            14
# 80            11
# 100           11
#             ...
# 6,008,868      1
# 706,886        1
# 2,874          1
# 904,365        1
# 628,800        1
# Name: Broilers and other meat-type chickens, Length: 1360, dtype: int64

# %%
farm_data['Cattle and calves'].value_counts()
# Out:
# (D)       36
# -         14
# 478        3
# 3,555      2
# 57,350     2
#           ..
# 7,710      1
# 7,910      1
# 31,293     1
# 8,134      1
# 21,399     1
# Name: Cattle and calves, Length: 2867, dtype: int64

# %%
farm_data['Hogs and pigs'].value_counts()
# Out:
# (D)        500
# -          170
# 56          15
# 36          13
# 72          12
#           ...
# 3,020        1
# 106,080      1
# 1,317        1
# 34,406       1
# 29,347       1
# Name: Hogs and pigs, Length: 1271, dtype: int64

# %%
farm_data['Sheep and lambs'].value_counts()
# Out:
# (D)       214
# -         158
# 409         8
# 72          8
# 120         8
#          ...
# 762         1
# 906         1
# 1,783       1
# 39,513      1
# 3,758       1
# Name: Sheep and lambs, Length: 1565, dtype: int64

# %%
farm_data[np.equal.outer(farm_data.to_numpy(copy=False),  ["(Z)"]).any(axis=1).all(axis=1)].shape
# Out:
# (32, 16)

# %%
farm_data[np.equal.outer(farm_data.to_numpy(copy=False),  ["-"]).any(axis=1).all(axis=1)].shape
# Out:
# (604, 16)

# %%
farm_data.replace(to_replace=["(Z)", "-"], value=0, inplace=True)

# %%
farm_data = farm_data[farm_data["Broilers and other meat-type chickens"].str.contains("(D)")==False]
farm_data = farm_data[farm_data["Cattle and calves"].str.contains("(D)")==False]
farm_data = farm_data[farm_data["Hogs and pigs"].str.contains("(D)")==False]
farm_data = farm_data[farm_data["Sheep and lambs"].str.contains("(D)")==False]
farm_data = farm_data[farm_data["Land in Farms"].str.contains("(D)")==False]
farm_data = farm_data[farm_data["Pastureland"].str.contains("(D)")==False]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# /usr/local/lib/python3.7/dist-packages/pandas/core/strings.py:2001: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)

# %%
farm_data2 = farm_data 
farm_data2
# Out:
#             State               County  ... Hogs and pigs Sheep and lambs
# 0    Pennsylvania  Westmoreland County  ...         1,164           2,087
# 1       Tennessee      Franklin County  ...           935             622
# 2      California        Fresno County  ...         3,200          30,883
# 3       Tennessee          Dyer County  ...         3,512             262
# 4    Pennsylvania   Susquehanna County  ...           282           1,436
# ..            ...                  ...  ...           ...             ...
# 465  North Dakota        Ramsey County  ...        37,926             536
# 466      Nebraska       Douglas County  ...         2,849             246
# 467  North Dakota        Morton County  ...           153           2,129
# 474          Ohio     Coshocton County  ...        70,578           3,542
# 475          Ohio      Clermont County  ...           288             276
#
# [1646 rows x 16 columns]

# %%
farm_data.replace(",",'', inplace=True, regex=True)
farm_data
# Out:
#             State               County  ... Hogs and pigs Sheep and lambs
# 0    Pennsylvania  Westmoreland County  ...          1164            2087
# 1       Tennessee      Franklin County  ...           935             622
# 2      California        Fresno County  ...          3200           30883
# 3       Tennessee          Dyer County  ...          3512             262
# 4    Pennsylvania   Susquehanna County  ...           282            1436
# ..            ...                  ...  ...           ...             ...
# 465  North Dakota        Ramsey County  ...         37926             536
# 466      Nebraska       Douglas County  ...          2849             246
# 467  North Dakota        Morton County  ...           153            2129
# 474          Ohio     Coshocton County  ...         70578            3542
# 475          Ohio      Clermont County  ...           288             276
#
# [1646 rows x 16 columns]

# %%
farm_data2
state_county = farm_data2[['State','County']]

# %% [markdown]
# Pastureland * Land in Farms = Acres of Pastureland

# %%
cols = farm_data2.columns[2:]
cols


farm_data_num = farm_data2[cols].apply(pd.to_numeric, errors = 'coerce')
farm_data_num.info()
farm_data_num
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1646 entries, 0 to 475
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Number of Farms                        1646 non-null   int64
#  1   Land in Farms                          1646 non-null   int64
#  2   Average Size of Farms                  1646 non-null   int64
#  3   Farm Size 1-9 acres                    1646 non-null   int64
#  4   Farm Size 10-49 acres                  1646 non-null   int64
#  5   Farm Size 50-179 acres                 1646 non-null   int64
#  6   Farm Size 180-499                      1646 non-null   int64
#  7   Farm Size 500-999                      1646 non-null   int64
#  8   Farm Size 1000+                        1646 non-null   int64
#  9   Pastureland                            1646 non-null   int64
#  10  Broilers and other meat-type chickens  1646 non-null   int64
# ...

# %%
cleaned_farm_data = pd.concat([state_county, farm_data_num], axis=1)
cleaned_farm_data
# Out:
#             State               County  ...  Hogs and pigs  Sheep and lambs
# 0    Pennsylvania  Westmoreland County  ...           1164             2087
# 1       Tennessee      Franklin County  ...            935              622
# 2      California        Fresno County  ...           3200            30883
# 3       Tennessee          Dyer County  ...           3512              262
# 4    Pennsylvania   Susquehanna County  ...            282             1436
# ..            ...                  ...  ...            ...              ...
# 465  North Dakota        Ramsey County  ...          37926              536
# 466      Nebraska       Douglas County  ...           2849              246
# 467  North Dakota        Morton County  ...            153             2129
# 474          Ohio     Coshocton County  ...          70578             3542
# 475          Ohio      Clermont County  ...            288              276
#
# [1646 rows x 16 columns]

# %%
cleaned_farm_data["Pastureland Acres"] = cleaned_farm_data["Pastureland"]*cleaned_farm_data["Land in Farms"]/100
cleaned_farm_data
# Out:
#             State               County  ...  Sheep and lambs  Pastureland Acres
# 0    Pennsylvania  Westmoreland County  ...             2087           20198.92
# 1       Tennessee      Franklin County  ...              622           21347.83
# 2      California        Fresno County  ...            30883          411635.00
# 3       Tennessee          Dyer County  ...              262           11353.48
# 4    Pennsylvania   Susquehanna County  ...             1436           23161.35
# ..            ...                  ...  ...              ...                ...
# 465  North Dakota        Ramsey County  ...              536           13932.22
# 466      Nebraska       Douglas County  ...              246            4540.45
# 467  North Dakota        Morton County  ...             2129          625226.34
# 474          Ohio     Coshocton County  ...             3542           31034.35
# 475          Ohio      Clermont County  ...              276           11681.04
#
# ...

# %%
florida = cleaned_farm_data.loc[farm_data['State']=='Florida']

# %%
print("Number of pigs: " + str(florida['Hogs and pigs'].sum()))
print("Number of cows: " + str(florida['Cattle and calves'].sum()))
print("Number of sheep: " + str(florida['Sheep and lambs'].sum()))
print("Number of chickens: " + str(florida['Broilers and other meat-type chickens'].sum()))
# Out:
# Number of pigs: 11960
# Number of cows: 1263920
# Number of sheep: 21277
# Number of chickens: 12199723

# %%
cleaned_farm_data["Chicken CH4 per Acre (Kg/Year)"] = cleaned_farm_data['Broilers and other meat-type chickens']*.1/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Cow CH4 per Acre (Kg/Year)"] = cleaned_farm_data['Cattle and calves']*69.5/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Sheep CH4 per Acre (Kg/Year)"] = cleaned_farm_data['Sheep and lambs']*.5/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Pig CH4 per Acre (Kg/Year)"] = cleaned_farm_data['Hogs and pigs']*12/cleaned_farm_data["Pastureland Acres"]

# %%
cleaned_farm_data["Chicken CO2 per Acre (Kg/Year)"] = cleaned_farm_data['Broilers and other meat-type chickens']*6*2.6*.62/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Cow CO2 per Acre (Kg/Year)"] = cleaned_farm_data['Cattle and calves']*60*340/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Sheep CO2 per Acre (Kg/Year)"] = cleaned_farm_data['Sheep and lambs']*20*30/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Pig CO2 per Acre (Kg/Year)"] = cleaned_farm_data['Hogs and pigs']*7*130*.7/cleaned_farm_data["Pastureland Acres"]

# %%
cleaned_farm_data["Chicken N2O per Acre (Kg/Year)"] = cleaned_farm_data['Broilers and other meat-type chickens']*.00004*365/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Cow N2O per Acre (Kg/Year)"] = cleaned_farm_data['Cattle and calves']*.48*365/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Sheep N2O per Acre (Kg/Year)"] = cleaned_farm_data['Sheep and lambs']*.16*365/cleaned_farm_data["Pastureland Acres"]
cleaned_farm_data["Pig N2O per Acre (Kg/Year)"] = cleaned_farm_data['Hogs and pigs']*.83*365/cleaned_farm_data["Pastureland Acres"]

# %%
plt.bar(x=cleaned_farm_data.index, height=cleaned_farm_data['Cow CO2 per Acre (Kg/Year)'])
# Out:
# <BarContainer object of 1646 artists>

# %%
cleaned_farm_data.head()
# Out:
#           State  ... Pig N2O per Acre (Kg/Year)
# 0  Pennsylvania  ...                  17.458052
# 1     Tennessee  ...                  13.268714
# 2    California  ...                   2.355096
# 3     Tennessee  ...                  93.712271
# 4  Pennsylvania  ...                   3.688554
#
# [5 rows x 29 columns]

# %%
cleaned_farm_data.describe()
# Out:
#        Number of Farms  ...  Pig N2O per Acre (Kg/Year)
# count      1646.000000  ...                 1646.000000
# mean        833.235115  ...                 1144.283316
# std         551.057242  ...                 5199.437157
# min          14.000000  ...                    0.003877
# 25%         478.000000  ...                    0.822908
# 50%         707.000000  ...                    4.289995
# 75%        1041.500000  ...                   52.019744
# max        5108.000000  ...                97170.904801
#
# [8 rows x 27 columns]

# %%
total_ch4 = cleaned_farm_data['Chicken CH4 per Acre (Kg/Year)'].sum() + cleaned_farm_data['Cow CH4 per Acre (Kg/Year)'].sum() + cleaned_farm_data['Sheep CH4 per Acre (Kg/Year)'].sum() + cleaned_farm_data['Pig CH4 per Acre (Kg/Year)'].sum()

# %%
total_co2 = cleaned_farm_data['Chicken CO2 per Acre (Kg/Year)'].sum() + cleaned_farm_data['Cow CO2 per Acre (Kg/Year)'].sum() + cleaned_farm_data['Sheep CO2 per Acre (Kg/Year)'].sum() + cleaned_farm_data['Pig CO2 per Acre (Kg/Year)'].sum()

# %%
total_n2o = cleaned_farm_data['Chicken N2O per Acre (Kg/Year)'].sum() + cleaned_farm_data['Cow N2O per Acre (Kg/Year)'].sum() + cleaned_farm_data['Sheep N2O per Acre (Kg/Year)'].sum() + cleaned_farm_data['Pig N2O per Acre (Kg/Year)'].sum()

# %%
print(total_ch4)
print(total_co2)
print(total_n2o)
print(total_ch4 + total_co2 + total_n2o)
# Out:
# 240403.56954071077
# 51124503.10950676
# 2290627.3618108123
# 53655534.04085828

# %%
# Find percentile of total amount of each greenhouse gas

# %%
#exporting cleaned data frame to csv
cleaned_farm_data.to_csv('cleaned_farm_data.csv')
